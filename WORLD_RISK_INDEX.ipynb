# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.10'

# %%
import pandas as pd
data = pd.read_csv("/content/WORLD RISK INDEX.csv")
data.head()
# Out:
#         Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0      Vanuatu  32.00     56.33          56.81           37.14
# 1        Tonga  29.08     56.04          51.90           28.94
# 2  Philippinen  24.32     45.09          53.93           34.99
# 3    Salomonen  23.51     36.40          64.60           44.11
# 4    Guatemala  20.88     38.42          54.35           35.36
#
#    Lack of Coping Capabilities   Lack of Adaptive Capacities  Year  \
# 0                        79.34                         53.96  2011
# 1                        81.80                         44.97  2011
# 2                        82.78                         44.01  2011
# 3                        85.95                         63.74  2011
# 4                        77.83                         49.87  2011
#
#   Exposure Category WRI Category Vulnerability Category  \
# 0         Very High    Very High                   High
# 1         Very High    Very High                 Medium
# ...

# %%
data.shape
# Out:
# (1917, 12)

# %%
from pycaret.regression import *
s = setup(data = data, target = 'WRI', session_id=123)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target               WRI
# 2                            Original Data        (1917, 12)
# 3                           Missing Values              True
# 4                         Numeric Features                 5
# 5                     Categorical Features                 6
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (1341, 324)
# 10                    Transformed Test Set        (576, 324)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %% [markdown]
# RUN AND COMPARE MODEL PERFORMANCE

# %%
best = compare_models()
# Out:
#                                     Model     MAE        MSE     RMSE  \
# br                         Bayesian Ridge  0.2337     0.1681   0.4059
# et                  Extra Trees Regressor  0.1881     0.1780   0.4079
# ridge                    Ridge Regression  0.2591     0.1868   0.4297
# omp           Orthogonal Matching Pursuit  0.3057     0.2372   0.4811
# gbr           Gradient Boosting Regressor  0.3192     0.2756   0.5058
# rf                Random Forest Regressor  0.2194     0.3196   0.5256
# dt                Decision Tree Regressor  0.2676     0.3441   0.5679
# knn                 K Neighbors Regressor  0.4266     0.5446   0.7079
# lightgbm  Light Gradient Boosting Machine  0.2586     0.8772   0.7774
# huber                     Huber Regressor  0.5051     1.1064   1.0368
# en                            Elastic Net  0.6425     1.1862   1.0809
# lasso                    Lasso Regression  0.6391     1.1941   1.0840
# ...

# %% [markdown]
# THREE LINE OF FOR MODEL PERFORMANCE OF WORLD RISK INDEX DATASET

# %%
from pycaret.regression import *
s = setup(data = data, target='WRI', silent=True)
cm = compare_models()
# Out:
#                                     Model           MAE           MSE  \
# br                         Bayesian Ridge  2.185000e-01  1.532000e-01
# ridge                    Ridge Regression  2.528000e-01  1.941000e-01
# omp           Orthogonal Matching Pursuit  3.032000e-01  2.269000e-01
# et                  Extra Trees Regressor  2.053000e-01  5.250000e-01
# rf                Random Forest Regressor  2.310000e-01  5.899000e-01
# gbr           Gradient Boosting Regressor  3.497000e-01  6.797000e-01
# dt                Decision Tree Regressor  2.847000e-01  6.373000e-01
# lightgbm  Light Gradient Boosting Machine  2.523000e-01  8.748000e-01
# knn                 K Neighbors Regressor  4.733000e-01  8.015000e-01
# huber                     Huber Regressor  5.021000e-01  1.154300e+00
# en                            Elastic Net  6.187000e-01  1.107700e+00
# lasso                    Lasso Regression  6.162000e-01  1.124500e+00
# ...

# %% [markdown]
# MODEL PERFORMANCE USING NORMALIZATION

# %%
s = setup(data = data, target = 'WRI', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE        MSE     RMSE  \
# br                         Bayesian Ridge  0.2072     0.1542   0.3746
# ridge                    Ridge Regression  0.2438     0.1842   0.4153
# par          Passive Aggressive Regressor  0.2572     0.1908   0.4175
# huber                     Huber Regressor  0.2203     0.1935   0.4229
# omp           Orthogonal Matching Pursuit  0.2914     0.2257   0.4637
# et                  Extra Trees Regressor  0.1931     0.3786   0.4922
# gbr           Gradient Boosting Regressor  0.3391     0.3678   0.5710
# rf                Random Forest Regressor  0.2244     0.4583   0.5862
# dt                Decision Tree Regressor  0.2861     0.9092   0.7866
# knn                 K Neighbors Regressor  0.4326     0.8271   0.8230
# lightgbm  Light Gradient Boosting Machine  0.2725     1.2170   0.8630
# ada                    AdaBoost Regressor  0.8349     1.2578   1.1172
# ...

# %% [markdown]
# MODEL PERFORMANCE USING FEATURE SELECTION

# %%
s = setup(data = data, target = 'WRI', feature_selection = True, feature_selection_threshold = 0.9, silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE       MSE     RMSE       R2  \
# br                         Bayesian Ridge  0.2254    0.1844   0.4178   0.9940
# ridge                    Ridge Regression  0.2494    0.1870   0.4236   0.9938
# et                  Extra Trees Regressor  0.1916    0.2228   0.4261   0.9934
# gbr           Gradient Boosting Regressor  0.3263    0.2292   0.4689   0.9923
# omp           Orthogonal Matching Pursuit  0.3118    0.2512   0.4942   0.9914
# rf                Random Forest Regressor  0.2177    0.3097   0.5016   0.9907
# lightgbm  Light Gradient Boosting Machine  0.2350    0.5536   0.6352   0.9841
# knn                 K Neighbors Regressor  0.4149    0.5093   0.6846   0.9837
# dt                Decision Tree Regressor  0.2970    0.8905   0.8380   0.9736
# huber                     Huber Regressor  0.5038    1.0547   1.0069   0.9656
# en                            Elastic Net  0.6371    1.1301   1.0503   0.9620
# ...

# %% [markdown]
# MODEL PERFORMANCE USING OUTLIER REMOVAL

# %%
s = setup(data = data, target = 'WRI', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# br                         Bayesian Ridge  0.2158   0.1581  0.3892  0.9943
# ridge                    Ridge Regression  0.2548   0.1871  0.4252  0.9933
# et                  Extra Trees Regressor  0.1897   0.2152  0.4278  0.9929
# rf                Random Forest Regressor  0.2102   0.2739  0.4633  0.9925
# gbr           Gradient Boosting Regressor  0.3323   0.2631  0.4892  0.9917
# omp           Orthogonal Matching Pursuit  0.3156   0.2413  0.4868  0.9912
# dt                Decision Tree Regressor  0.2752   0.3993  0.5996  0.9878
# knn                 K Neighbors Regressor  0.4620   0.7519  0.7967  0.9786
# lightgbm  Light Gradient Boosting Machine  0.2993   1.4624  0.9701  0.9633
# ada                    AdaBoost Regressor  0.7844   1.0656  1.0269  0.9618
# huber                     Huber Regressor  0.5018   1.2763  1.0695  0.9610
# ...

# %% [markdown]
# Model Performance using "Transformation"

# %%
s = setup(data = data, target = 'WRI', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model      MAE          MSE      RMSE  \
# et                  Extra Trees Regressor   0.1691       0.1430    0.3442
# rf                Random Forest Regressor   0.2056       0.2375    0.4456
# gbr           Gradient Boosting Regressor   0.3287       0.2487    0.4869
# dt                Decision Tree Regressor   0.2646       0.3147    0.5420
# lightgbm  Light Gradient Boosting Machine   0.2647       1.0118    0.7951
# knn                 K Neighbors Regressor   0.4625       0.9990    0.9694
# ada                    AdaBoost Regressor   0.7915       1.1007    1.0474
# br                         Bayesian Ridge   0.4607       1.1365    1.0333
# ridge                    Ridge Regression   0.5267       1.2267    1.0732
# omp           Orthogonal Matching Pursuit   0.4957       1.3492    1.1377
# par          Passive Aggressive Regressor   0.6549       1.4809    1.1794
# huber                     Huber Regressor   0.4916       2.3930    1.4264
# ...

# %% [markdown]
# Model Performance using "PCA"

# %%
s = setup(data = data, target = 'WRI', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  0.1313   0.1639  0.3308  0.9959
# gbr           Gradient Boosting Regressor  0.3304   0.4624  0.6248  0.9866
# rf                Random Forest Regressor  0.2633   0.5886  0.6407  0.9846
# dt                Decision Tree Regressor  0.3609   0.5822  0.7464  0.9824
# knn                 K Neighbors Regressor  0.4672   0.6919  0.7743  0.9806
# lightgbm  Light Gradient Boosting Machine  0.3060   0.9969  0.8628  0.9746
# lr                      Linear Regression  0.6559   1.2239  1.1016  0.9603
# br                         Bayesian Ridge  0.6559   1.2239  1.1016  0.9603
# lar                Least Angle Regression  0.6559   1.2239  1.1016  0.9603
# ridge                    Ridge Regression  0.6559   1.2239  1.1016  0.9603
# en                            Elastic Net  0.6773   1.2460  1.1097  0.9602
# ...

# %% [markdown]
# Model Performance using "Outlier Removal" + "Normalization"

# %%
s = setup(data = data, target = 'WRI', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model      MAE          MSE      RMSE  \
# br                         Bayesian Ridge   0.1981       0.1170    0.3354
# ridge                    Ridge Regression   0.2319       0.1454    0.3742
# huber                     Huber Regressor   0.2086       0.1744    0.4077
# par          Passive Aggressive Regressor   0.2777       0.1890    0.4262
# omp           Orthogonal Matching Pursuit   0.2939       0.2003    0.4428
# rf                Random Forest Regressor   0.2066       0.3015    0.4710
# et                  Extra Trees Regressor   0.1855       0.3089    0.4648
# gbr           Gradient Boosting Regressor   0.3372       0.4154    0.5757
# lightgbm  Light Gradient Boosting Machine   0.2265       0.5148    0.5737
# knn                 K Neighbors Regressor   0.4197       0.6514    0.7657
# dt                Decision Tree Regressor   0.2826       0.6667    0.7249
# ada                    AdaBoost Regressor   0.8599       1.3914    1.1596
# ...

# %% [markdown]
# Model Performance using "Outlier Removal" + "Normalization" + "Transformation"

# %%
s = setup(data = data, target = 'WRI', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model       MAE           MSE      RMSE  \
# et                  Extra Trees Regressor    0.1919  2.729000e-01    0.4779
# gbr           Gradient Boosting Regressor    0.3328  3.014000e-01    0.5328
# rf                Random Forest Regressor    0.2216  3.575000e-01    0.5525
# br                         Bayesian Ridge    0.3850  5.950000e-01    0.7293
# lightgbm  Light Gradient Boosting Machine    0.2538  7.728000e-01    0.7368
# dt                Decision Tree Regressor    0.2854  7.078000e-01    0.7645
# ridge                    Ridge Regression    0.4730  7.565000e-01    0.8215
# omp           Orthogonal Matching Pursuit    0.4276  7.722000e-01    0.8460
# par          Passive Aggressive Regressor    0.5494  8.186000e-01    0.8711
# knn                 K Neighbors Regressor    0.4787  1.232400e+00    1.0738
# ada                    AdaBoost Regressor    0.8656  1.484100e+00    1.2042
# ...

# %% [markdown]
# Build a single model - "RandomForest"

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

s = setup(data =  data, target='WRI', silent=True)

rfModel = create_model('rf')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# Fold
# 0     0.2096  0.2595  0.5094  0.9929  0.0319  0.0332
# 1     0.3137  0.6638  0.8148  0.9853  0.0437  0.0347
# 2     0.2088  0.1331  0.3649  0.9961  0.0347  0.0299
# 3     0.3245  1.9724  1.4044  0.9577  0.0400  0.0301
# 4     0.1932  0.3343  0.5782  0.9834  0.0390  0.0416
# 5     0.1945  0.1578  0.3973  0.9949  0.0345  0.0266
# 6     0.1476  0.0487  0.2206  0.9977  0.0312  0.0250
# 7     0.2246  0.2344  0.4842  0.9916  0.0360  0.0310
# 8     0.2246  0.1944  0.4409  0.9928  0.0385  0.0275
# 9     0.1751  0.1255  0.3542  0.9960  0.0274  0.0218
# Mean  0.2216  0.4124  0.5569  0.9888  0.0357  0.0301
# Std   0.0535  0.5443  0.3198  0.0113  0.0045  0.0053
# INFO:logs:create_model_container: 1
# INFO:logs:master_model_container: 1
# INFO:logs:display_container: 2
# INFO:logs:RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
# ...

# %% [markdown]
# save the trained model

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=559, verbose=0, warm_start=False), model_name=rfModelFile, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='WRI',
# ...

# %% [markdown]
# load the model

# %%
rfModel = load_model('rfModelFile')
# Out:
# INFO:logs:Initializing load_model()
# INFO:logs:load_model(model_name=rfModelFile, platform=None, authentication=None, verbose=True)
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
#  Get new dataset

# %%
import pandas as pd
newdata = pd.read_csv("/content/WORLD RISK INDEX.csv").iloc[:10]
newdata.head()
# Out:
#         Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0      Vanuatu  32.00     56.33          56.81           37.14
# 1        Tonga  29.08     56.04          51.90           28.94
# 2  Philippinen  24.32     45.09          53.93           34.99
# 3    Salomonen  23.51     36.40          64.60           44.11
# 4    Guatemala  20.88     38.42          54.35           35.36
#
#    Lack of Coping Capabilities   Lack of Adaptive Capacities  Year  \
# 0                        79.34                         53.96  2011
# 1                        81.80                         44.97  2011
# 2                        82.78                         44.01  2011
# 3                        85.95                         63.74  2011
# 4                        77.83                         49.87  2011
#
#   Exposure Category WRI Category Vulnerability Category  \
# 0         Very High    Very High                   High
# 1         Very High    Very High                 Medium
# ...

# %% [markdown]
# Make prediction on new dataset

# %%
newPredictions = predict_model(rfModel, data = newdata)
newPredictions
# Out:
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='WRI',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='m...
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=None,
# ...

# %% [markdown]
#  Scatter plot b/w actual and predicted

# %%
import matplotlib.pyplot as plt

predicted = newPredictions.iloc[:,-1]
actual = newPredictions.iloc[:,-2]

plt.scatter(actual, predicted)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Actual Vs Predicted')
plt.savefig("result-scatter-plot.jpg", dpi=300)
plt.show()

# %% [markdown]
# Save prediction results to csv

# %%
newPredictions.to_csv("NewPredictions.csv")

# %% [markdown]
# Feature Importance using Random Forest

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %% [markdown]
# Feature Importance using Extra Trees Regressor

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %% [markdown]
# Feature Importance using Decision Tree

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................
